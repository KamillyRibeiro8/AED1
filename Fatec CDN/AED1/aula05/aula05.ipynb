# %%
Cálculo da Área

# %%
base= float(input("Entre com base"))
altura= float(input("Entre com altura"))
area= base * altura
print("-Area é igual a: ", area)
# Out:
# Entre com base 1
# Entre com altura 5
# -Area é igual a:  5.0
