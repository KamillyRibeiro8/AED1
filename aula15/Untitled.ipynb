# %%
1) Em um cercado existem vários patos e coelhos. Escreva uma função em linguagem
Python que recebe como parâmetro o total de cabeças e o total de pés, e retorne dois
valores: o total de patos e o total de coelhos que se encontram nesse cercado. (4,0
pontos)
Teste essa função elaborando um script que vai receber do usuário dois valores. Para
tanto, leve em consideração que os dois últimos dígitos de seu RA sejam iguais a Y.
Entrada de Dados: Total de Cabeças: Y = _________
 Total de Pés: Y*3 = _________
Levando em consideração o resultado de seu script... Responda:
Total de Patos:___________________ Total de Coelhos: ___________________

# %%
def num(cabeças, patas):
    coelhos = (patas - (2 * cabeças)) // 2
    patos = cabeças - coelhos
    return patos, coelhos
    
while True:
    patos = 0
    coelhos = 0
    c = int(input("Digite o numero de cabeças: "))
    p = int(input("Digite o numero de patas: "))
    print("Você tem um total de 
    
    print(f"Patos: {patos}")
    print(f"coelhos: {coelhos}")
    break
# Out:
#   Cell In[34], line 11
#     return patos, coelhos
#     ^
# SyntaxError: 'return' outside function

# %%
2) Faça um script em Python que recebe como entrada um número positivo no formato de
String. Esse script deve devolver dois valores: o total da soma de todos os dígitos desse
número e o valor da multiplicação de todos esses mesmos dígitos. Por exemplo: Se a
entrada for 1234, o script deve devolver como resultado: Soma = 10 e Multiplicação =
24. (3,0 pontos)
Passe o número completo de seu RA para o script, e responda:
RA = _____________________________
Multiplicação = _____________________
Soma = ___________________________
# Out:
#   Cell In[25], line 1
#     2) Faça um script em Python que recebe como entrada um número positivo no formato de
#      ^
# SyntaxError: unmatched ')'

# %%
while True:
    Num = input("Insira um numéro positivo correspondente ao seu RA:")
    inteiro = list(Num)
    soma = 0
    multiplicacao = 1
    
    for inteiro in Num:
        digito = int(inteiro)
        soma =  soma + digito
        multiplicacao = multiplicacao * digito
        
    print("RA: ", Num)
    print("Multiplicação: ", multiplicacao)
    print("Soma: ", soma)
        
         break
# Out:
# Insira um numéro positivo correspondente ao seu RA: 1234
# RA:  1234
# Multiplicação:  24
# Soma:  10
