# %% [markdown]
# # Lista de exercícios AED1 - Parte 1

# %% [markdown]
# ### Exercício 0 - Faça um algoritmo para ler um número e mostrar se ele é par ou impar, positivo ou negativo.

# %%
numero = float(input("digite um número: "))
if numero >= 0:
    if numero %2 == 0:
        print("O número é Par e positivo")
    else:
        print("O número é impar e positivo")
elif numero < 0:
    if numero %2 == 0:
        print("O número é Par e negativo")
    else:
        print("O número é impar e negativo")
# Out:
# digite um número:  -7
# O número é impar e negativo

# %% [markdown]
# ### Exercício 1 - Faça um Programa que peça dois números e imprima o maior deles.

# %%
num_1 = float(input("digite o primeiro número: "))
num_2 = float(input("digite o segundo número: "))
if num_1 > num_2:
    print(f"O número {num_1} é maior que {num_2}")
elif num_2 > num_1:
    print(f"O número {num_2} é maior que {num_1}")
else:
    print("os números são iguais")
# Out:
# digite o primeiro número:  5
# digite o segundo número:  2
# O número 5.0 é maior que 2.0

# %% [markdown]
# ### Exercício 2 - Faça um Programa que peça um valor e mostre na tela se o valor é positivo ou negativo.

# %%
numero = float(input("digite um valor: "))
if numero >= 0:
    print("O valor é positivo")
else:
    print("O valor é negativo")
# Out:
# digite um valor:  -0.5
# O valor é negativo

# %% [markdown]
# ### Exercício 3 - Faça um Programa que verifique se uma letra digitada é vogal ou consoante.

# %%
letra = input("Digite uma letra: ").upper()
if letra == "A" or letra == "E" or letra == "I" or letra == "O" or letra == "U":
    print(f"A letra {letra} é uma vogal")
else:
    print(f"A letra {letra} é uma consoante")
# Out:
# Digite uma letra:  a
# A letra A é uma vogal

# %% [markdown]
# ### Exercício 4 - Faça um programa para a leitura de duas notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e apresentar:
# ##### a. A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;
# ##### b. A mensagem "Reprovado", se a média for menor do que sete;
# ##### c. A mensagem "Aprovado com Distinção", se a média for igual a dez.

# %%
num_1 = float(input("Digite a nota 1: "))
num_2 = float(input("Digite a nota 2: "))

if (num_1 + num_2)/2 == 10:
    print("Aprovado com Distinção")
elif (num_1 + num_2)/2 >= 7:
    print("Aprovado")
else:
    print("Reprovado")
# Out:
# Digite a nota 1:  5
# Digite a nota 2:  5
# Reprovado

# %% [markdown]
# ### Exercício 5 - Faça um programa que pergunte o preço de três produtos e informe qual produto você deve comprar, sabendo que a decisão é sempre pelo mais barato.

# %%
prod_1 = float(input("Valor do primeiro produto: "))
prod_2 = float(input("Valor do segundo produto: "))
prod_3 = float(input("Valor do terceiro produto: "))

if prod_1 < prod_2 and prod_1 < prod_3:
    print(f"Você deveria comprar o produto 1 que custa: {prod_1}: ")
elif prod_2 < prod_1 and prod_2 < prod_3:
    print(f"Você deveria comprar o produto 2 que custa: {prod_2}: ")
else:
    print(f"Você deveria comprar o produto 3 que custa: {prod_3}: ")
# Out:
# Valor do primeiro produto:  5
# Valor do segundo produto:  4
# Valor do terceiro produto:  10
# Você deveria comprar o produto 2 que custa: 4.0:

# %% [markdown]
# ### Exercício 6 - Faça um Programa que leia três números e mostre-os em ordem decrescente.

# %% [markdown]
# n1 = float(input("Insira um número:"))
# n2 = float(input("Insira um número:"))
# n3 = float(input("Insira um número:"))
# if n1 >= n2 and n1 >= n3:
#     if n2 >= n3:
#         print(n1, n2, n3)
#     else:
#         print(n1, n3, n2)
# elif n2 >= n1 and n2 >= n3:
#     if n1 >= n3:
#         print(n2, n1, n3)
#     else:
#         print(n2, n3, n1)
# else:
#     if n1 >= n2:
#         print(n3, n1, n2)
#     else:
#         print(n3, n2, n1)

# %%
n1 = float(input("Insira um número:"))
n2 = float(input("Insira um número:"))
n3 = float(input("Insira um número:"))
if n1 >= n2 and n1 >= n3:
    if n2 >= n3:
        print(n1, n2, n3)
    else:
        print(n1, n3, n2)
elif n2 >= n1 and n2 >= n3:
    if n1 >= n3:
        print(n2, n1, n3)
    else:
        print(n2, n3, n1)
else:
    if n1 >= n2:
        print(n3, n1, n2)
    else:
        print(n3, n2, n1)
# Out:
# Insira um número: 2
# Insira um número: 3
# Insira um número: 4
# 4.0 3.0 2.0

# %% [markdown]
# ### Exercício 7 - Faça um Programa que pergunte em que turno você estuda. Peça para digitar M-matutino ou V-Vespertino ou N- Noturno.
# Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

# %%
print("Por favor, digite o seu turno (M-matutino ou V-Vespertino ou N- Noturno): ")
turno = input("Insira qual o seu turno").upper()
if turno == "M":
    print("Bom Dia!")
elif turno == "V":
    print("Boa Tarde!")
elif turno == "N":
    print("Boa Noite!")
else:
    print("Valor inválido")
# Out:
# Por favor, digite o seu turno (M-matutino ou V-Vespertino ou N- Noturno):
# Insira qual o seu turno c
# Valor inválido

# %% [markdown]
# ### Exercício 8 - As Organizações Tabajara resolveram dar um aumento de salário aos seus colaboradores e lhe contraram para desenvolver o programa que calculará os reajustes.
# #### a. Faça um programa que recebe o salário de um colaborador e o reajuste segundo o seguinte critério, baseado no  salário atual:
#
# #### b. salários até R$ 280,00 (incluindo) : aumento de 20%
#
# #### c. salários entre R$ 280,00 e R$ 700,00 : aumento de 15%
#
# #### d. salários entre R$ 700,00 e R$ 1500,00 : aumento de 10%
#
# #### e. salários de R$ 1500,00 em diante : aumento de 5% Após o aumento ser realizado, informe na tela:
#
# #### f. o salário antes do reajuste;
#
# #### g. o percentual de aumento aplicado;
#
# #### h. o valor do aumento;
#
# #### i. o novo salário, após o aumento.

# %%
salario = float(input("Digite o valor do seu salário: "))
salario_1 = salario + (salario * 0.20)
salario_2 = salario + (salario * 0.15)
salario_3 = salario + (salario * 0.10)
salario_4 = salario + (salario * 0.05)

if salario <= 280:
    print(f"O valor do seu salário antes do reajuste é:{salario}.")
    print("Percentual de aumento aplicado: 20%")
    print(F"Valor do aumento é: {salario * 0.20}")
    print(f"Salário após o aumento é:{salario_1}")
    
elif salario <= 700:
    print(f"O valor do seu salário antes do reajuste é:{salario}.")
    print("Percentual de aumento aplicado: 15%")
    print(F"Valor do aumento é: {salario * 0.15}")
    print(f"Salário após o aumento é:{salario_2}")
    
elif salario <= 1500:
    print(f"O valor do seu salário antes do reajuste é:{salario}.")
    print("Percentual de aumento aplicado: 10%")
    print(F"Valor do aumento é: {salario * 0.10}")
    print(f"Salário após o aumento é:{salario_3}")
    
elif salario > 1500:
    print(f"O valor do seu salário antes do reajuste é:{salario}.")
    print("Percentual de aumento aplicado: 5%")
    print(F"Valor do aumento é: {salario * 0.05}")
    print(f"Salário após o aumento é:{salario_4}")
# Out:
# digite o valor do seu salário:  700
# O valor do seu salário antes do reajuste é:700.0.
# Percentual de aumento aplicado: 15%
# Valor do aumento é: 105.0
# Salário após o aumento é:805.0

# %% [markdown]
# ### Exercício 9 - Faça um programa para o cálculo de uma folha de pagamento, sabendo que os descontos são do Imposto de Renda, que depende do salário bruto (conforme tabela abaixo) e 3% para o Sindicato e que o FGTS corresponde a 11% do Salário Bruto, mas não é descontado (é a empresa que deposita). O Salário Líquido corresponde ao Salário Bruto menos os descontos. O programa deverá pedir ao usuário o valor da sua hora e a quantidade de horas trabalhadas no mês.

# %% [markdown]
# ##### a. Desconto do IR:
#
# ##### b. Salário Bruto até 900 (inclusive) - isento
#
# ##### c. Salário Bruto até 1500 (inclusive) - desconto de 5%
#
# ##### d. Salário Bruto até 2500 (inclusive) - desconto de 10%
#
# ##### e. Salário Bruto acima de 2500 - desconto de 20% Imprima na tela as informações, dispostas conforme o exemplo
#
# ##### abaixo. No exemplo o valor da hora é 5 e a quantidade de hora é 220

# %%
hora = float(input("Digite o valor da sua hora de trabalho: "))
n_hora = float(input("Digite a quantidade de horas trabalhadas no mês")
salario_1 = hora * n_hora
salario_2 = salario - (salario * 0.05)
salario_3 = salario - (salario * 0.10)
salario_4 = salario - (salario * 0.20)

if salario <= 900:
    print(f"Salário bruto: (hora * n_hora) :{salario_1}.")
    print(f"(-) IR (hora) : {n_hora}")
    print(F"Valor do aumento é: {salario * 0.20}")
    print(f"Salário após o aumento é:{salario_1}")
# Out:
# Salário bruto: (10.0 * 240.0): R$ 2400.0
# (-) IR 10: R$ 240.0
# (-) Sindicato (3%) :72.0
# (-) FGTS : 264.0:
# Total de descontos: 312.0
# Salário liquido: 2088.0

# %% [markdown]
# ### 10 - Faça um programa que lê as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre, e calcule
# a sua média. A atribuição de conceitos obedece à tabela abaixo:

# %% [markdown]
# ##### a.   Média de Aproveitamento  Conceito
#
# ##### b.   Entre 9.0 e 10.0        A
#
# ##### c.   Entre 7.5 e 9.0         B
#
# ##### d.   Entre 6.0 e 7.5         C
#
# ##### e.   Entre 4.0 e 6.0         D
#
# ##### f.   Entre 4.0 e zero        E

# %%
not1 = float(input(" Digite a primeira nota: "))
not2 = float(input(" Digite a segunda nota: "))
media = (num1 + num2)/2
if media >= 9.0:
    print("Seu Conceito é: A ")
elif media >= 7.5:
    print("Seu Conceito é: B ")
elif media >= 6.0:
    print("Seu Conceito é: C ")
elif media >= 4.0:
    print("Seu Conceito é: D ")
else:
    print("Seu Conceito é: E ")
# Out:
#  Digite a primeira nota:  6
#  Digite a segunda nota:  6
# Seu Conceito é: C
